# %% [markdown]
# # Transformada de Fourier
#
# Sea $f(x)$ una función conocida en $N$ puntos separados uniformemente dentro del intervalo $[a, b]$, con $a = x_0$ y $b = x_0 + L$. Es decir, una función _discretizada_. La transformada discreta de Fourier (DFT) $\hat{f}$ de $f$ es el análogo discreto de la serie de Fourier de una función continua. Se obtiene con:
#
# $$
# \hat{f}_m = \sum_{n = 0}^{N - 1} c_ne^{2\pi i\frac{nm}{N}}
# $$
#
# Los coeficientes se calculan con:
#
# $$
# c_n = \frac{1}{N} \sum_{k = 0}^{N - 1} f_ke^{-2\pi i\frac{nk}{N}}
# $$
#
# donde $f_k = f(x_0 + k\frac{L}{N})$.

# %%
import numpy as np
from cmath import exp
from math import pi
import matplotlib.pyplot as plt

# %% [markdown]
# Primero voy a probar la implementación de numpy, para después comparar con la mía.

# %%
N = 500
a = 0.0
b = 16.0

x = np.linspace(a, b, N)
funcion_prueba = np.sin(x)

plt.plot(x, funcion_prueba)

# %%
f_trans = np.fft.fft(funcion_prueba)

X = [i.real for i in f_trans]
Y = [i.imag for i in f_trans]

plt.scatter(X, Y)

# %%
plt.plot(x, X)

# %%
plt.plot(x, np.abs(f_trans))

# %% [markdown]
# Bueno, no sé si esto está bien, pero va a ser mi referencia.
#
# Primer intento:

# %%
a = complex(2, 3)
b = 2 + 3j

print(type(a), type(b))
# Out:
# <class 'complex'> <class 'complex'>

# %%
# Esta función calcula el n-ésimo coeficiente de la transformada
def coeficiente_de_fourier(f, delta, N, n):
    suma_k = 0.0
    for k in range(N):
        suma_k += f[k] * exp(-2.0 * pi * n * k / N)
    return suma_k / N

# %%
# Esta función calcula un punto de la transformada de Fourier
# de una función discretizada
def transformada_de_fourier(funcion, delta, m): # delta es la distancia entre los puntos de f conocidos
    N = len(funcion)
    f_hat_m = 0.0
    for n in range(N):
        f_hat_m += coeficiente_de_fourier(funcion, delta, N, n) * exp(2.0 * pi * n * m / N)
    return f_hat_m

# %% [markdown]
# #### Ejemplo

# %%
N = 100
# Pongamos que la función se conoce en el intervalo [a, b]
a = 0.0
b = 1.0
delta = abs(b - a) / N

x = np.linspace(a, b, N)
funcion_prueba = np.sin(x)
f_hat = []

for i in range(N):
    f_hat.append(transformada_de_fourier(funcion_prueba, delta, i))

# %%
X = [x.real for x in f_hat]
Y = [x.imag for x in f_hat]

plt.scatter(X, Y)

# %% [markdown]
# No luce bien.
#
# Segundo intento:

# %%
def DFT(funcion):
    N = len(funcion)
    suma_fou = 0.0
    
    for n in range(N):
        for m in range(N):
            suma_fou += funcion[m] * exp(2.0 * pi * n * ())
